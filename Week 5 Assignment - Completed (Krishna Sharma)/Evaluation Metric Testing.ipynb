# %%
# !find /kaggle/input -maxdepth 3
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/krishna26code
# /kaggle/input/datasets/krishna26code/tiger-project
# /kaggle/input/datasets/krishna26code/test-metrics-py

# %%
# !cp -r "/kaggle/input/datasets/krishna26code/tiger-project/Recommender_System" /kaggle/working/
# !cp "/kaggle/input/datasets/krishna26code/test-metrics-py/test_metrics.py" /kaggle/working/Recommender_System/
# %cd /kaggle/working/Recommender_System
# !python test_metrics.py
# Out:
# /kaggle/working/Recommender_System
# Computed : {'recall@5': 0.75, 'ndcg@5': 0.4717132018086354}
# Expected : recall@5 = 0.75  ndcg@5 = 0.4717132018086354
#
# PASSED: metric implementation matches hand-computed values.
